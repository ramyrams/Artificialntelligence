# %% [markdown]
# <a href="https://colab.research.google.com/github/ramyrams/Artificialntelligence/blob/master/Car_License_Detection_Using_Yolo_V10_Custom_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Change runtime type to T4 GPU
#
# data folder:
# https://drive.google.com/drive/u/0/folders/186PAi8NBjA_DrImOwO5ZcZPNHafIRtJ5

# %%
# nvidia-smi: Stands for: NVIDIA System Management Interface
# Purpose: Command-line utility to monitor NVIDIA GPUs
# !nvidia-smi
# Out:
# Mon May 26 20:18:29 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# Clone Yolov10 repo
# Should create under the folder yolov10
# Go to Colab> File to view the foldr yolov10
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# Cloning into 'yolov10'...
# remote: Enumerating objects: 20338, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 20338 (delta 2), reused 0 (delta 0), pack-reused 20334 (from 2)
# Receiving objects: 100% (20338/20338), 11.10 MiB | 25.43 MiB/s, done.
# Resolving deltas: 100% (14354/14354), done.

# %%
# % magic command, ells Jupyter/Colab this is a special command
# %cd yolov10
# Out:
# /content/yolov10

# %%
# !pwd
# Out:
# /content/yolov10

# %%
ls
# Out:
# app.py           docs/      flops.py  mkdocs.yml      requirements.txt
# CONTRIBUTING.md  examples/  LICENSE   pyproject.toml  tests/
# docker/          figures/   logs/     README.md       ultralytics/

# %%
# install all the requested packages
# !pip install .
# Out:
# Processing /content/yolov10
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 117.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 63.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 43.5 MB/s eta 0:00:00
# ...

# %%
import os
import urllib.request

#create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), "weights")
if not os.path.isdir(weights_dir):
  os.mkdir(weights_dir)

# URLs of the weight files
urls = [
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt"
]

for url in urls:
  file_name = os.path.basename(url)
  file_path = os.path.join(weights_dir, file_name)
  urllib.request.urlretrieve(url, file_path)
  print(f"Downloaded {file_name} to {file_path}")
# Out:
# Downloaded yolov10n.pt to /content/yolov10/weights/yolov10n.pt
# Downloaded yolov10s.pt to /content/yolov10/weights/yolov10s.pt
# Downloaded yolov10m.pt to /content/yolov10/weights/yolov10m.pt
# Downloaded yolov10b.pt to /content/yolov10/weights/yolov10b.pt
# Downloaded yolov10x.pt to /content/yolov10/weights/yolov10x.pt

# %%
# Upload the dataset Vehicle Detection.v7i.yolov9.zip to yolov10 folder

# %%
# !unzip VehicleDetection.v7i.yolov9.zip
# Out:
# Archive:  VehicleDetection.v7i.yolov9.zip
# replace README.dataset.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: Y
#   inflating: README.dataset.txt
# replace README.roboflow.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace README.roboflow.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace README.roboflow.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace README.roboflow.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace README.roboflow.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace README.roboflow.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/133025397_08a395143c_z_jpg.rf.513652522c4047daee3a9e23875a7b7d.jpg
# ...

# %% [markdown]
# Upload data.yaml from the downloaded dataset to root level

# %%
# !yolo task=detect mode=train epochs=100 batch=16 plots=True model=weights/yolov10n.pt data=data.yaml
# Out:
# New https://pypi.org/project/ultralytics/8.3.145 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.11.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls
# Out:
# app.py		 docs	   mkdocs.yml		runs
# build		 examples  pyproject.toml	tests
# CONTRIBUTING.md  figures   README.dataset.txt	ultralytics
# custom_dataset	 flops.py  README.md		ultralytics.egg-info
# data.yaml	 LICENSE   README.roboflow.txt	VehicleDetection.v7i.yolov9.zip
# docker		 logs	   requirements.txt	weights

# %%
#Upload car.jpep car image

# !yolo task=detect mode=predict conf=0.25 save=True model=runs/detect/train4/weights/best.pt source=car.jpg

# out: it should create the prediction in the \runs\detect\preduct\car.jpeg file with the prediction
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.11.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv10n summary (fused): 285 layers, 2695196 parameters, 0 gradients, 8.2 GFLOPs
#
# image 1/1 /content/yolov10/car.jpg: 512x640 1 licence, 67.8ms
# Speed: 3.9ms preprocess, 67.8ms inference, 116.6ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Upload the video 2103099-hd_1280_720_60fps.mp4
# !yolo task=detect mode=predict conf=0.25 save=True model=runs/detect/train4/weights/best.pt source=2103099-hd_1280_720_60fps.mp4
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.11.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv10n summary (fused): 285 layers, 2695196 parameters, 0 gradients, 8.2 GFLOPs
#
# video 1/1 (frame 1/3600) /content/yolov10/2103099-hd_1280_720_60fps.mp4: 384x640 1 licence, 84.0ms
# video 1/1 (frame 2/3600) /content/yolov10/2103099-hd_1280_720_60fps.mp4: 384x640 1 licence, 11.2ms
# video 1/1 (frame 3/3600) /content/yolov10/2103099-hd_1280_720_60fps.mp4: 384x640 1 licence, 10.1ms
# video 1/1 (frame 4/3600) /content/yolov10/2103099-hd_1280_720_60fps.mp4: 384x640 (no detections), 13.1ms
# video 1/1 (frame 5/3600) /content/yolov10/2103099-hd_1280_720_60fps.mp4: 384x640 1 licence, 15.7ms
# video 1/1 (frame 6/3600) /content/yolov10/2103099-hd_1280_720_60fps.mp4: 384x640 2 licences, 11.3ms
# video 1/1 (frame 7/3600) /content/yolov10/2103099-hd_1280_720_60fps.mp4: 384x640 2 licences, 10.3ms
# video 1/1 (frame 8/3600) /content/yolov10/2103099-hd_1280_720_60fps.mp4: 384x640 2 licences, 9.8ms
# ...
